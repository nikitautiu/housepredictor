# %%
# %matplotlib inline
# standard
import sys
import os

# pandas
import pandas as pd

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# needed for project imports
sys.path.append(os.path.join(os.getcwd(), "../.."))

# project imports
from housepredictor.extractor import DictMultiExtractor


# this styling is purely my preference
# less chartjunk
sns.set_context('notebook', font_scale=1.5, rc={'line.linewidth': 2.5})
sns.set(style='ticks', palette='Set2')

# %%
# read the data 
raw_data = pd.read_json('../data/raw/scrape-results.json')
raw_dict = raw_data.loc[0, 'data']
raw_dict
# Out:
# {'AangebodenSinds': '/Date(1497823200000+0200)/',
#  'AangebodenSindsTekst': '5 dagen',
#  'AanmeldDatum': '/Date(1262300400000+0100)/',
#  'AantalBadkamers': 2,
#  'AantalKamers': 6,
#  'AantalKavels': None,
#  'AantalSlaapkamers': None,
#  'AantalWoonlagen': '3 woonlagen',
#  'Aanvaarding': 'In overleg',
#  'Adres': 'Nico Jessekade 27',
#  'AfgekochtDatum': '/Date(2742764400000+0100)/',
#  'Afstand': 0,
#  'BalkonDakterras': None,
#  'BedrijfsruimteCombinatieObject': None,
#  'BezichtingDagdelen': [{'Naam': 'Geen voorkeur', 'Waarde': 'Geen voorkeur'},
#   {'Naam': "'s ochtends", 'Waarde': "'s ochtends"},
#   {'Naam': "'s middags", 'Waarde': "'s middags"}],
#  'BezichtingDagen': [{'Naam': 'Geen voorkeur', 'Waarde': 'Geen voorkeur'},
#   {'Naam': 'Alleen werkdagen', 'Waarde': 'Alleen werkdagen'},
#   {'Naam': 'Maandag', 'Waarde': 'Maandag'},
#   {'Naam': 'Dinsdag', 'Waarde': 'Dinsdag'},
#   {'Naam': 'Woensdag', 'Waarde': 'Woensdag'},
#   {'Naam': 'Donderdag', 'Waarde': 'Donderdag'},
#   {'Naam': 'Vrijdag', 'Waarde': 'Vrijdag'}],
#  'BijdrageVVE': None,
#  'Bijzonderheden': '',
#  'Bouwjaar': '2008',
#  'Bouwvorm': 'bestaande bouw',
#  'BronCode': 'NVM',
#  'ChildrenObjects': [],
#  'ContactpersoonEmail': '',
#  'ContactpersoonTelefoon': '',
#  'Cv': None,
#  'DatumAanvaarding': None,
#  'DatumOndertekeningAkte': None,
#  'Deeplink': None,
#  'DetailInfo': {'HasPromotionLabel': True,
#   'PromotionLabelType': 1,
#   'RibbonColor': 1,
#   'RibbonText': None,
#   'Tagline': 'Top huis,top locatie,5 slaapkamers,2 badkamers,2 pp. Aan water,prachtig afgewerkt. Snel beschikbaar.'},
#  'EersteHuurPrijs': None,
#  'EersteHuurPrijsLang': None,
#  'EersteKoopPrijs': None,
#  'EersteKoopPrijsLang': None,
#  'EigendomsSituatie': 'erfpacht (afgekocht tot <{AfgekochtDatum}> tot einddatum erfpacht met optie tot afkopen)',
#  'Energielabel': {'Definitief': True,
#   'Index': None,
#   'Label': 'A',
#   'NietBeschikbaar': False,
#   'NietVerplicht': False},
#  'ErfpachtBedrag': 0,
#  'Foto': 'http://cloud.funda.nl/valentina_media/081/833/561_klein.jpg',
#  'FotoLarge': 'http://cloud.funda.nl/valentina_media/081/833/561_groot.jpg',
#  'FotoLargest': 'http://cloud.funda.nl/valentina_media/081/833/561_grotere.jpg',
#  'FotoMedium': 'http://cloud.funda.nl/valentina_media/081/833/561_middel.jpg',
#  'FotoSecure': 'http://cloud.funda.nl/valentina_media/081/833/561_klein.jpg',
#  'Garage': 'garage met carport',
#  'GarageIsolatie': None,
#  'GarageVoorzieningen': 'elektra',
#  'GelegenOp': None,
#  'GewijzigdDatum': '/Date(1498119666000+0200)/',
#  'GlobalId': 3842583,
#  'GroupByObjectType': 'c3606b1e-34ca-4501-b1c6-f25daf3288bc',
#  'Heeft360GradenFoto': True,
#  'HeeftBrochure': True,
#  'HeeftOpenhuizenTopper': False,
#  'HeeftOverbruggingsgrarantie': False,
#  'HeeftPlattegrond': True,
#  'HeeftTophuis': False,
#  'HeeftVeiling': False,
#  'HeeftVideo': True,
#  'HoofdFoto': 'http://cloud.funda.nl/valentina_media/081/833/561_groot.jpg',
#  'HoofdFotoSecure': 'http://cloud.funda.nl/valentina_media/081/833/561_groot.jpg',
#  'HoofdTuinType': 'achtertuin',
#  'HuurPrijs': None,
#  'HuurPrijsLang': None,
#  'HuurPrijsTot': None,
#  'Huurprijs': None,
#  'HuurprijsFormaat': None,
#  'Id': 3842583,
#  'InUnitsVanaf': None,
#  'IndBasisPlaatsing': True,
#  'IndFotos': True,
#  'IndIpix': True,
#  'IndOpenhuizenTopper': False,
#  'IndPDF': True,
#  'IndPlattegrond': True,
#  'IndProjectObjectType': False,
#  'IndTop': False,
#  'IndTransactieMakelaarTonen': None,
#  'IndVeilingProduct': False,
#  'IndVideo': True,
#  'Inhoud': 535,
#  'InternalId': 'c3606b1e-34ca-4501-b1c6-f25daf3288bc',
#  'IsIngetrokken': False,
#  'IsSearchable': True,
#  'IsVerhuurd': False,
#  'IsVerkocht': False,
#  'IsVerkochtOfVerhuurd': False,
#  'Isolatie': None,
#  'Kenmerken': [{'Ad': None,
#    'Kenmerken': [{'Naam': 'Vraagprijs',
#      'NaamCss': None,
#      'Waarde': '<span class="price-wrapper">€\xa0700.000 k.k.</span>',
#      'WaardeCss': None},
#     {'Naam': 'Aangeboden sinds',
#      'NaamCss': None,
#      'Waarde': '19 juni 2017',
#      'WaardeCss': None},
#     {'Naam': 'Status',
#      'NaamCss': None,
#      'Waarde': 'Beschikbaar',
#      'WaardeCss': None},
#     {'Naam': 'Aanvaarding',
#      'NaamCss': None,
#      'Waarde': 'In overleg',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Overdracht'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Soort woonhuis',
#      'NaamCss': None,
#      'Waarde': 'Eengezinswoning, geschakelde woning',
#      'WaardeCss': None},
#     {'Naam': 'Bouwvorm',
#      'NaamCss': None,
#      'Waarde': 'Bestaande bouw',
#      'WaardeCss': None},
#     {'Naam': 'Bouwjaar', 'NaamCss': None, 'Waarde': '2008', 'WaardeCss': None},
#     {'Naam': 'Soort dak',
#      'NaamCss': None,
#      'Waarde': 'Plat dak bedekt met bitumineuze dakbedekking',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Bouw'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Wonen (= woonoppervlakte) ',
#      'NaamCss': 'sub-cat',
#      'Waarde': '157&nbsp;m&sup2;',
#      'WaardeCss': None},
#     {'Naam': 'Externe bergruimte',
#      'NaamCss': 'sub-cat',
#      'Waarde': '25&nbsp;m&sup2;',
#      'WaardeCss': None},
#     {'Naam': 'Perceeloppervlakte',
#      'NaamCss': None,
#      'Waarde': '174&nbsp;m&sup2;',
#      'WaardeCss': None},
#     {'Naam': 'Inhoud',
#      'NaamCss': None,
#      'Waarde': '535&nbsp;m&sup3;',
#      'WaardeCss': None}],
#    'SubKenmerk': {'Ad': '<a class="item-blueprint pos-r" href="/koop/amsterdam/huis-49297946-nico-jessekade-27/plattegrond/">Plattegrond</a>',
#     'Kenmerken': [],
#     'SubKenmerk': None,
#     'Titel': '<strong>Gebruiksoppervlakten</strong>'},
#    'Titel': 'Oppervlakten en inhoud'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Aantal kamers',
#      'NaamCss': None,
#      'Waarde': '6 kamers (5 slaapkamers)',
#      'WaardeCss': None},
#     {'Naam': 'Aantal badkamers',
#      'NaamCss': None,
#      'Waarde': '2 badkamers en 2 aparte toiletten',
#      'WaardeCss': None},
#     {'Naam': 'Badkamervoorzieningen',
#      'NaamCss': None,
#      'Waarde': 'Ligbad, 2 douches en toilet',
#      'WaardeCss': None},
#     {'Naam': 'Aantal woonlagen',
#      'NaamCss': None,
#      'Waarde': '3 woonlagen',
#      'WaardeCss': None},
#     {'Naam': 'Voorzieningen',
#      'NaamCss': None,
#      'Waarde': 'Mechanische ventilatie en TV kabel',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Indeling'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Energielabel',
#      'NaamCss': None,
#      'Waarde': 'A ',
#      'WaardeCss': 'a'},
#     {'Naam': 'Verwarming',
#      'NaamCss': None,
#      'Waarde': 'Stadsverwarming',
#      'WaardeCss': None},
#     {'Naam': 'Warm water',
#      'NaamCss': None,
#      'Waarde': 'Centrale voorziening',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Energie'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Amsterdam AU 1366',
#      'NaamCss': 'sub-cat frst',
#      'Waarde': 'Amsterdam AU 1366',
#      'WaardeCss': 'sub-cat frst'},
#     {'Naam': 'Oppervlakte',
#      'NaamCss': 'sub-cat',
#      'Waarde': '174 m² (deelperceel)',
#      'WaardeCss': None},
#     {'Naam': 'Eigendomssituatie',
#      'NaamCss': 'sub-cat',
#      'Waarde': 'Gemeentelijke erfpacht (einddatum erfpacht:  30-11-2056)',
#      'WaardeCss': None},
#     {'Naam': 'Lasten',
#      'NaamCss': 'sub-cat lst',
#      'Waarde': 'Afgekocht tot 30-11-2056',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Kadastrale gegevens'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Ligging',
#      'NaamCss': None,
#      'Waarde': 'Aan water, aan rustige weg, vrij uitzicht en aan vaarwater',
#      'WaardeCss': None},
#     {'Naam': 'Tuin',
#      'NaamCss': None,
#      'Waarde': 'Achtertuin en voortuin',
#      'WaardeCss': None},
#     {'Naam': 'Achtertuin',
#      'NaamCss': None,
#      'Waarde': '44 m² (7,4m diep en 6m breed)',
#      'WaardeCss': None},
#     {'Naam': 'Ligging tuin',
#      'NaamCss': None,
#      'Waarde': 'Gelegen op het noordoosten',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Buitenruimte'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Schuur/berging',
#      'NaamCss': None,
#      'Waarde': 'Vrijstaande stenen berging',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Bergruimte'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Soort garage',
#      'NaamCss': None,
#      'Waarde': 'Garage met carport',
#      'WaardeCss': None},
#     {'Naam': 'Capaciteit',
#      'NaamCss': None,
#      'Waarde': "2 auto's",
#      'WaardeCss': None},
#     {'Naam': 'Voorzieningen',
#      'NaamCss': None,
#      'Waarde': 'Elektra',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Garage'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Soort parkeergelegenheid',
#      'NaamCss': None,
#      'Waarde': 'Openbaar parkeren en betaald parkeren',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Parkeergelegenheid '}],
#  'KenmerkenKort': {'Ad': None,
#   'Kenmerken': [{'Naam': 'Soort woonhuis',
#     'NaamCss': None,
#     'Waarde': 'Eengezinswoning, geschakelde woning',
#     'WaardeCss': None},
#    {'Naam': 'Woonoppervlakte',
#     'NaamCss': None,
#     'Waarde': '157&nbsp;m&sup2;',
#     'WaardeCss': None},
#    {'Naam': 'Aantal kamers',
#     'NaamCss': None,
#     'Waarde': '6 kamers (5 slaapkamers)',
#     'WaardeCss': None},
#    {'Naam': 'Bijzonderheden',
#     'NaamCss': None,
#     'Waarde': 'Tuin, groen energie label, garage en Schuur/berging',
#     'WaardeCss': None},
#    {'Naam': 'Inhoud',
#     'NaamCss': None,
#     'Waarde': '535&nbsp;m&sup3;',
#     'WaardeCss': None}],
#   'SubKenmerk': None,
#   'Titel': None},
#  'KenmerkenTitel': None,
#  'KoopPrijs': 700000,
#  'KoopPrijsLang': '<[KoopPrijs]> <{kosten koper|kort}>',
#  'Koopprijs': 700000,
#  'KoopprijsFormaat': '<[KoopPrijs]> <{kosten koper|kort}>',
#  'KoopprijsTot': None,
#  'Ligging': 'aan water, aan rustige weg, vrij uitzicht en aan vaarwater',
#  'Makelaar': 'RET Makelaars',
#  'MakelaarId': 24763,
#  'MakelaarNaam': 'RET Makelaars',
#  'MakelaarTelefoon': '0207402020',
#  'MedeAanbieders': [],
#  'Media': [{'Categorie': 1,
#    'ContentType': 1,
#    'Id': '6e3c8c1c-9e4c-4fe4-aaee-790afc3caf61',
#    'IndexNumber': 1,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/561_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/561_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/561_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/561_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/561_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/561_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/561_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/561_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '372520b9-03fe-4bb0-b4d2-705415aea230',
#    'IndexNumber': 2,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/562_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/562_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/562_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/562_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/562_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/562_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/562_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/562_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '236287c7-88af-4ada-9980-a6ba37c11943',
#    'IndexNumber': 3,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/563_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/563_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/563_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/563_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/563_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/563_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/563_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/563_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '74adb151-f760-47ee-9c4a-ce50977c19d7',
#    'IndexNumber': 4,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/564_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/564_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/564_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/564_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/564_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/564_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/564_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/564_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '74bbc350-db7b-4d37-87a8-4b020db845a2',
#    'IndexNumber': 5,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/565_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/565_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/565_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/565_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/565_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/565_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/565_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/565_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'e843175f-caa8-498c-a783-84438e823c93',
#    'IndexNumber': 6,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/566_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/566_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/566_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/566_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/566_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/566_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/566_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/566_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '8cc254e6-9b39-4866-850c-7a05c6c4c0df',
#    'IndexNumber': 7,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/567_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/567_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/567_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/567_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/567_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/567_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/567_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/567_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'e9dc421c-39df-407b-9c11-d449057f177f',
#    'IndexNumber': 8,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/568_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/568_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/568_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/568_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/568_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/568_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/568_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/568_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '651c8fae-3c2b-45dd-b043-5024050bd2f1',
#    'IndexNumber': 9,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/569_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/569_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/569_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/569_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/569_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/569_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/569_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/569_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '32cdf221-2e3c-4e41-8d84-755b21a2f5f7',
#    'IndexNumber': 10,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/570_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/570_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/570_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/570_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/570_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/570_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/570_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/570_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'dbf21e1d-79a0-4bc9-9bd6-02e493d96782',
#    'IndexNumber': 11,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/571_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/571_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/571_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/571_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/571_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/571_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/571_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/571_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'a10a7879-fdf5-4ab7-b156-9039d2785cdb',
#    'IndexNumber': 12,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/572_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/572_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/572_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/572_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/572_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/572_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/572_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/572_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'f6652690-3996-4c7d-adac-899127ff5630',
#    'IndexNumber': 13,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/574_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/574_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/574_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/574_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/574_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/574_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/574_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/574_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'b1782979-efad-4b34-ba8b-f69b75fd5311',
#    'IndexNumber': 14,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/573_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/573_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/573_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/573_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/573_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/573_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/573_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/573_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '6ef27b10-98df-4d3e-aa31-a8a824ba4d84',
#    'IndexNumber': 15,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/575_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/575_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/575_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/575_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/575_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/575_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/575_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/575_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '0c4cb4de-902c-429d-9674-f3bd29cfa91c',
#    'IndexNumber': 16,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/577_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/577_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/577_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/577_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/577_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/577_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/577_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/577_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '8ed32241-65ae-4d3f-ac91-df7dc820b5ea',
#    'IndexNumber': 17,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/576_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/576_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/576_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/576_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/576_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/576_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/576_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/576_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '317a661e-97cd-4a10-a349-4bd8c5b6994e',
#    'IndexNumber': 18,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/578_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/578_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/578_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/578_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/578_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/578_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/578_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/578_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '7dca5243-cb78-4ef9-a11f-3004be6cfbb0',
#    'IndexNumber': 19,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/580_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/580_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/580_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/580_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/580_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/580_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/580_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/580_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '1b41d3bf-e4cb-4b2b-a300-91a450fdbf82',
#    'IndexNumber': 20,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/579_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/579_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/579_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/579_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/579_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/579_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/579_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/579_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '99d3fd75-0891-4a49-8b7e-ebd7b7ac5795',
#    'IndexNumber': 21,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/581_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/581_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/581_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/581_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/581_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/581_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/581_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/581_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '486030f5-1bb2-4fae-a951-f681703cefb7',
#    'IndexNumber': 22,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/583_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/583_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/583_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/583_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/583_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/583_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/583_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/583_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'fa9209cc-f524-4310-9a9e-2fadbda08c18',
#    'IndexNumber': 23,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/582_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/582_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/582_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/582_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/582_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/582_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/582_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/582_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '5c4645e5-8b15-4608-b9d3-0646d5e5362b',
#    'IndexNumber': 24,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/584_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/584_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/584_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/584_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/584_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/584_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/584_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/584_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '499238e5-c772-461d-b5d5-d149d0ddf785',
#    'IndexNumber': 25,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/585_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/585_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/585_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/585_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/585_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/585_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/585_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/585_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '2d343fc6-b365-4f4d-944e-8a964fcab7f1',
#    'IndexNumber': 26,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/586_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/586_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/586_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/586_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/586_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/586_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/586_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/586_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '8a689a60-11f5-43aa-a516-54b03ebf19f5',
#    'IndexNumber': 27,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/587_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/587_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/587_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/587_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/587_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/587_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/587_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/587_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '481e4ab7-8a5a-4222-8c76-02eda2188027',
#    'IndexNumber': 28,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/588_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/588_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/588_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/588_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/588_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/588_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/588_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/588_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '85c0f175-c0ee-4616-b69e-6bdcdba80510',
#    'IndexNumber': 29,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/589_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/589_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/589_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/589_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/589_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/589_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/589_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/589_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '1a2a1bfc-19ba-4849-b3ec-0054c0270f02',
#    'IndexNumber': 30,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/590_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/590_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/590_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/590_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/590_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/590_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/590_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/590_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'd1fe96c9-f9a2-40aa-897b-c0f2c0a79eb8',
#    'IndexNumber': 31,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/591_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/591_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/591_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/591_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/591_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/591_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/591_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/591_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '4feafbfd-fb51-4048-a2ef-93e9a1becf52',
#    'IndexNumber': 32,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/592_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/592_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/592_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/592_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/592_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/592_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/592_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/592_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'd38534ce-0352-4b75-98a2-0d29ca1db23c',
#    'IndexNumber': 33,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/593_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/593_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/593_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/593_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/593_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/593_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/593_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/593_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': '21c6e910-40de-442b-8672-fcc7301ae957',
#    'IndexNumber': 34,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/594_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/594_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/594_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/594_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/594_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/594_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/594_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/594_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'a3017d4d-2f34-4289-a811-1dd42059ac11',
#    'IndexNumber': 35,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/623_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/623_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/623_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/623_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/623_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/623_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/081/833/623_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/081/833/623_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'UPLOAD',
#    'RegistratieVerplicht': False,
# ...
#   'http://cloud.funda.nl/valentina_media/081/833/583_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/582_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/584_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/585_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/586_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/587_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/588_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/589_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/590_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/591_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/592_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/593_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/594_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/623_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/624_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/625_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/626_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/628_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/627_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/629_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/630_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/631_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/632_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/634_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/633_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/635_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/636_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/637_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/638_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/639_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/640_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/641_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/081/833/642_klein.jpg'],
#  'MobileURL': 'http://m.funda.nl/koop/amsterdam/huis-49297946-nico-jessekade-27/',
#  'Note': None,
#  'ObjectType': 'woonhuis',
#  'ObjectTypeMetVoorvoegsel': 'deze woning',
#  'OpenHuis': [],
#  'OpenHuizen': [],
#  'Oppervlakte': 0,
#  'PerceelOppervlakte': 174,
#  'Perceeloppervlakte': 174,
#  'PermanenteBewoning': 'permanente bewoning is toegestaan',
#  'Plaats': 'Amsterdam',
#  'Postcode': '1087MG',
#  'Prijs': {'GeenExtraKosten': None,
#   'HuurAbbreviation': '',
#   'Huurprijs': None,
#   'HuurprijsOpAanvraag': '',
#   'HuurprijsTot': None,
#   'KoopAbbreviation': 'k.k.',
#   'Koopprijs': 700000,
#   'KoopprijsOpAanvraag': '',
#   'KoopprijsTot': None,
#   'OriginelePrijs': None,
#   'VeilingText': ''},
#  'PrijsGeformatteerd': '<span class="price-wrapper"><span class="price">&euro;&nbsp;700.000</span> <abbr class="price-ext">k.k.</abbr></span>',
#  'PrijsGeformatteerdHtml': '<span class="price-wrapper"><span class="price">&euro;&nbsp;700.000</span> <abbr class="price-ext">k.k.</abbr></span>',
#  'PrijsGeformatteerdTextHuur': '<span class="price-wrapper"><span class="price">&euro;&nbsp;700.000</span> <abbr class="price-ext">k.k.</abbr></span>',
#  'PrijsGeformatteerdTextKoop': '<span class="price-wrapper"><span class="price">&euro;&nbsp;700.000</span> <abbr class="price-ext">k.k.</abbr></span>',
#  'Producten': ['Video', 'Plattegrond', '360-fotos', 'Brochure', 'Featured'],
#  'Project': None,
#  'ProjectNaam': None,
#  'PromoLabel': {'HasPromotionLabel': True,
#   'PromotionPhotos': ['http://cloud.funda.nl/valentina_media/081/833/562_klein.jpg',
#    'http://cloud.funda.nl/valentina_media/081/833/563_klein.jpg',
#    'http://cloud.funda.nl/valentina_media/081/833/564_klein.jpg',
#    'http://cloud.funda.nl/valentina_media/081/833/565_klein.jpg'],
#   'PromotionPhotosSecure': ['/081/833/562.jpg',
#    '/081/833/563.jpg',
#    '/081/833/564.jpg',
#    '/081/833/565.jpg'],
#   'PromotionType': 1,
#   'RibbonColor': 0,
#   'RibbonText': None,
#   'Tagline': 'Top huis,top locatie,5 slaapkamers,2 badkamers,2 pp. Aan water,prachtig afgewerkt. Snel beschikbaar.'},
#  'PublicatieDatum': '/Date(1497823200000+0200)/',
#  'PublicatieStatus': 0,
#  'SavedDate': None,
#  'SchuurBerging': 'vrijstaande stenen',
#  'SchuurBergingIsolatie': None,
#  'SchuurBergingVoorzieningen': None,
#  'ScrambledId': '49297946',
#  'ServiceKosten': None,
#  'ShortURL': 'http://funda.nl/49297946',
#  'Soort-aanbod': 'woonhuis',
#  'SoortAanbod': 10,
#  'SoortDak': 'plat dak bedekt met bitumineuze dakbedekking',
#  'SoortGarage': 'eengezinswoning, geschakelde woning',
#  'SoortParkeergelegenheid': 'eengezinswoning, geschakelde woning',
#  'SoortPlaatsing': 0,
#  'SoortWoning': 'eengezinswoning, geschakelde woning',
#  'StartOplevering': None,
#  'TimeAgoText': None,
#  'Titels': [{'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam',
#    'Pagina': 0},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Omschrijving',
#    'Pagina': 1},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Kenmerken',
#    'Pagina': 2},
#   {'Omschrijving': "Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Foto's",
#    'Pagina': 3},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Buurtinformatie',
#    'Pagina': 4},
#   {'Omschrijving': "Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Foto's",
#    'Pagina': 5},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Kaart',
#    'Pagina': 6},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Hypotheek',
#    'Pagina': 7},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Print',
#    'Pagina': 8},
#   {'Omschrijving': "Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - 360&deg; foto's",
#    'Pagina': 9},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Video',
#    'Pagina': 10},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Plattegrond',
#    'Pagina': 11},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Slideshow',
#    'Pagina': 12},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Reageer',
#    'Pagina': 13},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Bezichtiging',
#    'Pagina': 14},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Brochure',
#    'Pagina': 15},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Voorwaarden',
#    'Pagina': 16},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Openhuis',
#    'Pagina': 17},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Doorsturen',
#    'Pagina': 18},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Routeplanner',
#    'Pagina': 19},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Kadaster',
#    'Pagina': 20},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Overbruggingsgarantie',
#    'Pagina': 21},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - CarrouselBanner',
#    'Pagina': 22},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Carrousel',
#    'Pagina': 23},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - MeldEenFout',
#    'Pagina': 24},
#   {'Omschrijving': 'Huis te koop: Nico Jessekade 27 1087 MG Amsterdam - Woningtypen',
#    'Pagina': 25}],
#  'ToonBezichtigingMaken': True,
#  'ToonBrochureAanvraag': True,
#  'ToonMakelaarWoningaanbod': True,
#  'ToonReageren': True,
#  'TransactieAfmeldDatum': None,
#  'TransactieMakelaarId': None,
#  'TransactieMakelaarNaam': None,
#  'Tuin': 'achtertuin en voortuin',
#  'TuinLigging': 'gelegen op het noordoosten',
#  'TypeProject': 0,
#  'URL': 'http://www.funda.nl/koop/amsterdam/huis-49297946-nico-jessekade-27/',
#  'Veiling': {'EindDatum': None,
#   'Link': None,
#   'StartDatum': None,
#   'VeilingPartij': None},
#  'VeilingGeformatteerd': None,
#  'VerkoopStatus': 'Beschikbaar',
#  'Verwarming': 'stadsverwarming',
#  'Video': {'ImageUrl': 'http://quadia.webtvframework.com/funda/video/_function/attribute.image.retrieve?id=2317120',
#   'QuadiaVideoId': 2317120,
#   'ThumbnailUrl': 'http://quadia.webtvframework.com/funda/video/_function/attribute.image.retrieve?id=2317120',
#   'Videos': [{'BitRate': 796194,
#     'Cdns': [{'DeliveryType': 'download',
#       'FileType': None,
#       'MimeType': 'application/x-mpegurl',
#       'SslUrl': None,
#       'Url': 'http://d1jqky4nt0kbou.cloudfront.net/qwtv^97169936383800592.mp4'},
#      {'DeliveryType': 'download',
#       'FileType': None,
#       'MimeType': 'video/mp4',
#       'SslUrl': None,
#       'Url': 'https://d1jqky4nt0kbou.cloudfront.net/qwtv^97169936383800592.mp4'},
#      {'DeliveryType': 'streaming',
#       'FileType': None,
#       'MimeType': 'video/mp4',
#       'SslUrl': None,
#       'Url': 'rtmp://s3fgw58uk282ub.cloudfront.net/cfx/st/qwtv^97169936383800592.mp4'}],
#     'HasAudio': True,
#     'HasVideo': True,
#     'IsSource': False,
#     'Stream': {'AverageBitRate': 700052, 'Height': 360, 'Width': 640},
#     'Url': 'http://quadia-nfs.s3-eu-west-1.amazonaws.com/1_4100700.mp4?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAI266JGP4WRVGDWOA%2F20170623%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20170623T220058Z&X-Amz-Expires=90000&X-Amz-SignedHeaders=host&X-Amz-Signature=7e4da4350a02db6868332bedf5279c604ca4ea6f24f6c72c974bed2ec00bcee4'},
#    {'BitRate': 1523426,
#     'Cdns': [{'DeliveryType': 'download',
#       'FileType': None,
#       'MimeType': 'application/x-mpegurl',
#       'SslUrl': None,
#       'Url': 'http://d1jqky4nt0kbou.cloudfront.net/qwtv^97169936383800594.mp4'},
#      {'DeliveryType': 'download',
#       'FileType': None,
#       'MimeType': 'video/mp4',
#       'SslUrl': None,
#       'Url': 'https://d1jqky4nt0kbou.cloudfront.net/qwtv^97169936383800594.mp4'},
#      {'DeliveryType': 'streaming',
#       'FileType': None,
#       'MimeType': 'video/mp4',
#       'SslUrl': None,
#       'Url': 'rtmp://s3fgw58uk282ub.cloudfront.net/cfx/st/qwtv^97169936383800594.mp4'}],
#     'HasAudio': True,
#     'HasVideo': True,
#     'IsSource': False,
#     'Stream': {'AverageBitRate': 1395185, 'Height': 576, 'Width': 1024},
#     'Url': 'http://quadia-nfs.s3-eu-west-1.amazonaws.com/1_4100701.mp4?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAI266JGP4WRVGDWOA%2F20170623%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20170623T220058Z&X-Amz-Expires=90000&X-Amz-SignedHeaders=host&X-Amz-Signature=7435a05615ded9ddce6c5f6eb312121accd33251aa44b7d9ffc8f899d6fbd7c1'},
#    {'BitRate': 2518081,
#     'Cdns': [{'DeliveryType': 'download',
#       'FileType': None,
#       'MimeType': 'application/x-mpegurl',
#       'SslUrl': None,
#       'Url': 'http://d1jqky4nt0kbou.cloudfront.net/qwtv^97169936383800596.mp4'},
#      {'DeliveryType': 'download',
#       'FileType': None,
#       'MimeType': 'video/mp4',
#       'SslUrl': None,
#       'Url': 'https://d1jqky4nt0kbou.cloudfront.net/qwtv^97169936383800596.mp4'},
#      {'DeliveryType': 'streaming',
#       'FileType': None,
#       'MimeType': 'video/mp4',
#       'SslUrl': None,
#       'Url': 'rtmp://s3fgw58uk282ub.cloudfront.net/cfx/st/qwtv^97169936383800596.mp4'}],
#     'HasAudio': True,
#     'HasVideo': True,
#     'IsSource': False,
#     'Stream': {'AverageBitRate': 2389840, 'Height': 720, 'Width': 1280},
#     'Url': 'http://quadia-nfs.s3-eu-west-1.amazonaws.com/1_4100702.mp4?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAI266JGP4WRVGDWOA%2F20170623%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20170623T220058Z&X-Amz-Expires=90000&X-Amz-SignedHeaders=host&X-Amz-Signature=85d79206547cf60037f1cae4284e11b9643d8421773feb0e274293724960c0de'}]},
#  'VolledigeOmschrijving': '**PERFECT FAMILIEHUIS  VAN CIRCA 157 M² WAAR U DIRECT IN KAN TREKKEN. MAAR LIEFST 5 SLAAPKAMERS EN 2 PARKEERPLAATSEN! AAN HET WATER GELEGEN OP EEN MOOIE EN RUSTIGE LOCATIE OP DE RIETEILANDEN, AAN ÉÉN VAN DE MOOISTE STRATEN VAN IJBURG***\n\nHighlights;\n-Prachtig lichte woonkamer met aan beide kanten openslaande deuren naar de tuin. \n-Maar liefst 5 slaapkamers!\n-2 badkamers en 3 wc’s.\n-2 parkeerplaatsen aan de achterzijde van de woning (1 in de garage en 1 onder de carport).\n-Achterom alleen bereikbaar voor de bewoners van de Nico Jessekade. (Terrein is afgesloten met elektrisch hek, ideaal voor kleine kinderen).\n-Ruime hal met voldoende opberg- en garderobe ruimte.\n-Aan de voorkant van de woning bevinden zich zonneschermen. Hierdoor blijft de woning lekker koel. \n-Autoluwe straat, perfect voor spelende kinderen.\n-Prachtige gietvloer in de gehele woning.\n-Goed ingedeeld huis. De bovenste etage kan perfect gebruikt worden als ‘kinderafdeling’; 2 slaapkamers en een badkamer.\n-Designkeuken met kookeiland en inbouwapparatuur.\n-De woning is volledig afgewerkt en klaar om direct in te trekken. \n-Geen overburen, heerlijk veel privacy!\n-Optioneel: Steiger te koop tegenover het huis voor € 12.500,--.\n\nOverige bijzonderheden:\n-Bouwjaar is 2008.\n-Het woonoppervlak van circa 157,4m² is gemeten conform meetinstructies NVM, meetrapport is aanwezig.\n-Erfpacht is afgekocht voor 50 jaar tot 2056, dus tot die tijd geen jaarlijkse erfpachtbetalingen!\n-De kosten voor het mandelig binnenterrein en elektrische poort bedragen €105,- per jaar.\n\nIndeling:\nBegane grond; entree, hal met garderobe, toilet, woonkamer met aansluitend een open design keuken met kookeiland gelegen aan de tuinzijde. Tuin op het zuidwesten met eigen parkeerplaats aan de achterkant van de tuin (binnenplaats). \nEerste verdieping; overloop, 3 ruime slaapkamers, badkamer met douche, ligbad en wastafel, aparte toilet.\nTweede verdieping; overloop, 2 ruime slaapkamers, badkamer met toilet, wastafel en douche, en een aparte wasruimte. \nKortom; Ideaal gezinshuis gelegen aan de Nico Jessekade waar u direct in kunt trekken!\n\nLigging: \nIJburg is duidelijk in opkomst en biedt een jachthaven met vele restaurants aan het water, nieuwe trendy cafés, een filmhuis en theater, diverse activiteiten op het gebied van sport, kunst en cultuur, verschillende parken, een watersportvereniging en artistieke Amsterdamse winkeltjes. Opvallend aan de bevolkingssamenstelling is dat hier veel creatieve en ondernemende mensen wonen. Dit vind je terug in de bijzondere architectuur waar bewoners vaak zelf een hand in hebben gehad. \n\nHet Diemerpark, ter grootte van twee keer het Vondelpark en waar men naar hartenlust kan wandelen, hardlopen, fietsen en skaten, ligt op loopafstand. Er bevindt zich een voetbal- en hockeyclub en het park heeft zelfs een eigen strandje met zonneweide. IJburg kent nog een strand: Blijburg, een prachtig ruim strand aan het IJmeer, dagelijks toegankelijk om te zwemmen, zonnen of uit te waaien. Het gezellige strandpaviljoen verzorgt naast een hapje en een drankje ook regelmatig feesten en festivals voor alle leeftijden. \n\nOp het Haveneiland is een winkelcentrum met onder andere ambachtelijke verswinkels, diverse lunch- en espressobars, een grote Albert Heijn, een biologische supermarkt, de HEMA, Vomar, kappers, Action en Bruna met een PostNL-postkantoor. Op het plein achter het winkelcentrum is wekelijks een gezellige markt. Ook zijn er voorzieningen zoals basisscholen, het IJburg College voor voortgezet onderwijs (VWO, HAVO en VMBO), kinderopvang, bibliotheken, sportscholen en een medisch centrum. Daarnaast mag de grote jachthaven E. Peek vermeld worden; ook deze ligt op loopafstand. Door het vele omringende water en de bevaarbare grachten heeft IJburg een maritieme inslag.\n\nIJburg is een waterrijke, rustige en inspirerende omgeving. Een ideale locatie om te wonen met het centrum van Amsterdam via tram 26 op 10 minuten afstand ...
#  'Voorzieningen': 'mechanische ventilatie en TV kabel',
#  'WGS84_X': 4.999718,
#  'WGS84_Y': 52.35061,
#  'WarmWater': 'centrale voorziening',
#  'WoonOppervlakte': 157,
#  'WoonOppervlakteTot': 157,
#  'Woonoppervlakte': 157,
#  'Woonplaats': 'Amsterdam',
#  'ZoekType': [10]}

# %%
KEY_NAMES = [
'AangebodenSindsTekst',
'AanmeldDatum',
'AantalKamers',
'AantalKavels',
'Aanvaarding',
'Adres',
'Afstand',
'BronCode',
'DatumOndertekeningAkte',
'GewijzigdDatum',
'GlobalId',
'HeeftOpenhuizenTopper',
'HeeftOverbruggingsgrarantie',
'HeeftTophuis',
'HeeftVeiling',
'InUnitsVanaf',
'IsVerkocht',
'IsVerkochtOfVerhuurd',
'Koopprijs',
'KoopprijsTot',
'Note',
'Oppervlakte',
'Perceeloppervlakte',
'Postcode',
'Prijs.GeenExtraKosten',
'Prijs.OriginelePrijs',
'PromoLabel.HasPromotionLabel',
'PromoLabel.PromotionType',
'PromoLabel.RibbonColor',
'PublicatieDatum',
'PublicatieStatus',
'Soort-aanbod',
'SoortAanbod',
'StartOplevering',
'WGS84_X',
'WGS84_Y',
'WoonOppervlakteTot',
'Woonoppervlakte',
'AangebodenSinds',
'AantalBadkamers',
'AantalSlaapkamers',
'AantalWoonlagen',
'AfgekochtDatum',
'BalkonDakterras',
'BijdrageVVE',
'Bijzonderheden',
'Bouwjaar',
'Bouwvorm',
'EigendomsSituatie',
'Energielabel.Definitief',
'Energielabel.Index',
'Energielabel.Label',
'Energielabel.NietBeschikbaar',
'Energielabel.NietVerplicht',
'ErfpachtBedrag',
'Garage',
'GarageIsolatie',
'GarageVoorzieningen',
'GelegenOp',
'HoofdTuinType',
'IndBasisPlaatsing',
'Inhoud',
'IsIngetrokken',
'Isolatie',
'Ligging',
'ObjectType',
'ObjectTypeMetVoorvoegsel',
'PerceelOppervlakte',
'PermanenteBewoning',
'SchuurBerging',
'SchuurBergingIsolatie',
'SchuurBergingVoorzieningen',
'ServiceKosten',
'SoortDak',
'SoortGarage',
'SoortParkeergelegenheid',
'SoortPlaatsing',
'SoortWoning',
'ToonBezichtigingMaken',
'ToonBrochureAanvraag',
'ToonMakelaarWoningaanbod',
'ToonReageren',
'TuinLigging',
'Verwarming',
'VolledigeOmschrijving',
'Voorzieningen',
'WarmWater',
'WoonOppervlakte',
'WoonOppervlakteTot',
'KoopPrijs',
]

def extract_preliminary(data):
    extraction_specs = [{'key': key} for key in KEY_NAMES]
    extractor = DictMultiExtractor(extraction_specs, sep='.')
    return pd.DataFrame(data.apply(extractor).tolist())

# %%
data = extract_preliminary(raw_data['data'])

# %% [markdown]
# Remove duplicated columns
#
# This way we will know not to extract them in the first place, removing the need for this proprocessing step.

# %%
def duplicate_columns(df, return_dataframe = False, verbose = False):
    '''
        a function to detect and possibly remove duplicated columns for a pandas dataframe
    '''
    from pandas.core.common import array_equivalent
    # group columns by dtypes, only the columns of the same dtypes can be duplicate of each other
    groups = df.columns.to_series().groupby(df.dtypes).groups
    duplicated_columns = []

    for dtype, col_names in groups.items():
        column_values = df[col_names]
        num_columns = len(col_names)

        # find duplicated columns by checking pairs of columns, store first column name if duplicate exist 
        for i in range(num_columns):
            column_i = column_values.iloc[:,i].values
            for j in range(i + 1, num_columns):
                column_j = column_values.iloc[:,j].values
                if array_equivalent(column_i, column_j):
                    if verbose: 
                        print("column {} is a duplicate of column {}".format(col_names[i], col_names[j]))
                    duplicated_columns.append(col_names[i])
                    break
    if not return_dataframe:
        # return the column names of those duplicated exists
        return duplicated_columns
    else:
        # return a dataframe with duplicated columns dropped 
        return df.drop(labels = duplicated_columns, axis = 1)

# %%
duplicate_col_names = duplicate_columns(data)
deduplicated_data = duplicate_columns(data, return_dataframe=True)
data = deduplicated_data
# Out:
# /home/nikitautiu/anaconda2/envs/datascience3/lib/python3.6/site-packages/ipykernel_launcher.py:19: DeprecationWarning: 'pandas.core.common.array_equivalent' is deprecated and is no longer public API

# %% [markdown]
# Remove columns with too many missing values

# %% [markdown]
# Analyze what columns still have `object` as type, meaning that they are either text or should have more preprocessing done on them.

# %%
non_num_cols = data.dtypes[data.dtypes == object].index.tolist()
str_cols = data[non_num_cols]
print('\n'.join(non_num_cols))
str_cols.head()
# Out:
# AangebodenSindsTekst
# AanmeldDatum
# AantalWoonlagen
# Aanvaarding
# Adres
# AfgekochtDatum
# BalkonDakterras
# Bijzonderheden
# Bouwjaar
# Bouwvorm
# BronCode
# EigendomsSituatie
# Energielabel.Label
# Garage
# GarageIsolatie
# GarageVoorzieningen
# GelegenOp
# GewijzigdDatum
# HoofdTuinType
# Isolatie
# Ligging
# ObjectType
# ObjectTypeMetVoorvoegsel
# PermanenteBewoning
# Postcode
# PublicatieDatum
# SchuurBerging
# SchuurBergingIsolatie
# SchuurBergingVoorzieningen
# Soort-aanbod
# SoortDak
# SoortParkeergelegenheid
# SoortWoning
# StartOplevering
# TuinLigging
# Verwarming
# VolledigeOmschrijving
# Voorzieningen
# WarmWater
#   AangebodenSindsTekst                AanmeldDatum            AantalWoonlagen  \
# 0              5 dagen  /Date(1262300400000+0100)/                3 woonlagen
# 1              2 dagen  /Date(1262300400000+0100)/  2 woonlagen en een zolder
# 2              2 dagen  /Date(1262300400000+0100)/                3 woonlagen
# 3             2½ maand  /Date(1262300400000+0100)/                 1 woonlaag
# 4             2½ maand  /Date(1262300400000+0100)/                 1 woonlaag
#
#   Aanvaarding                         Adres              AfgekochtDatum  \
# 0  In overleg             Nico Jessekade 27  /Date(2742764400000+0100)/
# 1  In overleg                   Bombraak 31  /Date(2302210800000+0100)/
# 2  In overleg               Raphaëlplein 39                        None
# 3  In overleg            Stadionweg 198 III  /Date(2699215200000+0200)/
# 4  In overleg  Ben van Meerendonkstraat 293  /Date(2796588000000+0200)/
#
#    BalkonDakterras Bijzonderheden   Bouwjaar        Bouwvorm  \
# 0             None                      2008  bestaande bouw
# 1             None                      1993  bestaande bouw
# 2  balkon aanwezig                      1932  bestaande bouw
# 3  balkon aanwezig                      1931  bestaande bouw
# 4             None                 2001-2010  bestaande bouw
#
#            ...          Soort-aanbod  \
# 0          ...              woonhuis
# 1          ...              woonhuis
# 2          ...              woonhuis
# 3          ...           appartement
# 4          ...           appartement
#
#                                             SoortDak  \
# 0       plat dak bedekt met bitumineuze dakbedekking
# 1       plat dak bedekt met bitumineuze dakbedekking
# 2  samengesteld dak bedekt met dakpannen en bitum...
# 3  samengesteld dak bedekt met dakpannen en bitum...
# 4       plat dak bedekt met bitumineuze dakbedekking
#
#                SoortParkeergelegenheid                          SoortWoning  \
# 0  eengezinswoning, geschakelde woning  eengezinswoning, geschakelde woning
# 1        eengezinswoning, tussenwoning        eengezinswoning, tussenwoning
# 2                herenhuis, hoekwoning                herenhuis, hoekwoning
# 3            bovenwoning (appartement)            bovenwoning (appartement)
# 4            bovenwoning (appartement)            bovenwoning (appartement)
#
#   StartOplevering                 TuinLigging  \
# 0            None  gelegen op het noordoosten
# 1            None       gelegen op het zuiden
# 2            None                        None
# 3            None                        None
# 4            None                        None
#
#                                   Verwarming  \
# 0                            stadsverwarming
# 1                                 C.V.-ketel
# 2                                 C.V.-ketel
# 3                             blokverwarming
# 4  stadsverwarming en vloerverwarming geheel
#
#                                VolledigeOmschrijving  \
# 0  **PERFECT FAMILIEHUIS  VAN CIRCA 157 M² WAAR U...
# 1  Stel je voor: gezellig samen genieten van het ...
# 2  Een karatiristiek herenhuis uit de jaren 30, g...
# 3  Zeer ruim en sfeervol 5-kamerappartement met z...
# 4  Ben van Meerendonkstraat 293, 1087 LN AMSTERDA...
#
#                                        Voorzieningen             WarmWater
# 0                 mechanische ventilatie en TV kabel  centrale voorziening
# 1  alarminstallatie, buitenzonwering, jacuzzi, me...            C.V.-ketel
# 2  mechanische ventilatie, rolluiken, alarminstal...            C.V.-ketel
# 3                                           TV kabel  centrale voorziening
# 4           mechanische ventilatie, TV kabel en lift  centrale voorziening
#
# [5 rows x 39 columns]

# %% [markdown]
# Analyze which columns have the most missing data and remove them. Some might have null instead of a false value, but others might just be irrelevant to the analysis. Manual selection of features.

# %%
data = deduplicated_data
good_cols = [col_name for col_name in data.columns if data[col_name].unique().size >= 2]
good_cols
# Out:
# ['AangebodenSindsTekst',
#  'AantalBadkamers',
#  'AantalKamers',
#  'AantalWoonlagen',
#  'Aanvaarding',
#  'Adres',
#  'AfgekochtDatum',
#  'BalkonDakterras',
#  'BijdrageVVE',
#  'Bijzonderheden',
#  'Bouwjaar',
#  'Bouwvorm',
#  'BronCode',
#  'EigendomsSituatie',
#  'Energielabel.Definitief',
#  'Energielabel.Index',
#  'Energielabel.Label',
#  'Energielabel.NietBeschikbaar',
#  'Energielabel.NietVerplicht',
#  'ErfpachtBedrag',
#  'Garage',
#  'GarageIsolatie',
#  'GarageVoorzieningen',
#  'GelegenOp',
#  'GewijzigdDatum',
#  'GlobalId',
#  'HeeftVeiling',
#  'HoofdTuinType',
#  'Inhoud',
#  'Isolatie',
#  'Koopprijs',
#  'Ligging',
#  'ObjectType',
#  'ObjectTypeMetVoorvoegsel',
#  'PerceelOppervlakte',
#  'Perceeloppervlakte',
#  'PermanenteBewoning',
#  'Postcode',
#  'PromoLabel.HasPromotionLabel',
#  'PromoLabel.PromotionType',
#  'PromoLabel.RibbonColor',
#  'PublicatieDatum',
#  'SchuurBerging',
#  'SchuurBergingIsolatie',
#  'SchuurBergingVoorzieningen',
#  'ServiceKosten',
#  'Soort-aanbod',
#  'SoortDak',
#  'SoortParkeergelegenheid',
#  'SoortPlaatsing',
#  'SoortWoning',
#  'ToonBezichtigingMaken',
#  'ToonBrochureAanvraag',
#  'ToonMakelaarWoningaanbod',
#  'ToonReageren',
#  'TuinLigging',
#  'Verwarming',
#  'VolledigeOmschrijving',
#  'Voorzieningen',
#  'WGS84_X',
#  'WGS84_Y',
#  'WarmWater',
#  'WoonOppervlakte',
#  'Woonoppervlakte']
