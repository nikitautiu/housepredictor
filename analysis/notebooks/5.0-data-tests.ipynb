# %%
# %matplotlib inline
# standard
import sys
import os
import json

# pandas
import pandas as pd

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# needed for project imports
sys.path.append(os.path.join(os.getcwd(), "../.."))

# project imports
from housepredictor.extractor import extract_preliminary, DictMultiExtractor, sanitize_data, sanitize_record


# this styling is purely my preference
# less chartjunk
sns.set_context('notebook', font_scale=1.5, rc={'line.linewidth': 2.5})
sns.set(style='ticks', palette='Set2')

# %%
data = next(pd.read_csv('../data/raw/2017-08-05T14-08-53-items.csv', chunksize=2000))
rawdicts = [eval( data.loc[i, 'data']) for i in range(data.shape[0])]

# %%
KEY_NAMES = [
    'AantalBadkamers',
    'AantalKamers',
    'AantalWoonlagen',
    'Aanvaarding',
    'Adres',
    'AfgekochtDatum',
    'BalkonDakterras',
    'BijdrageVVE',
    'Bijzonderheden',
    'Bouwjaar',
    'Bouwvorm',
    'BronCode',
    'EigendomsSituatie',
    'Energielabel.Definitief',
    'Energielabel.Index',
    'Energielabel.Label',
    'Energielabel.NietBeschikbaar',
    'Energielabel.NietVerplicht',
    'ErfpachtBedrag',
    'Garage',
    'GarageIsolatie',
    'GarageVoorzieningen',
    'GelegenOp',
    'GlobalId',
    'Inhoud',
    'Isolatie',
    'Koopprijs',
    'Ligging',
    'PerceelOppervlakte',
    'Perceeloppervlakte',
    'PermanenteBewoning',
    'Postcode',
    'ShortURL',
    'PublicatieDatum',
    'SchuurBerging',
    'SchuurBergingIsolatie',
    'SchuurBergingVoorzieningen',
    'ServiceKosten',
    'Soort-aanbod',
    'SoortDak',
    'SoortParkeergelegenheid',
    'SoortPlaatsing',
    'SoortWoning',
    'TuinLigging',
    'Verwarming',
    'VolledigeOmschrijving',
    'Voorzieningen',
    'WGS84_X',
    'WGS84_Y',
    'WarmWater',
    'WoonOppervlakte',
    'Woonplaats',
]

# %%
rawdicts[10]
# Out:
# {'AangebodenSinds': '/Date(1304895958000+0200)/',
#  'AangebodenSindsTekst': '6+ maanden',
#  'AanmeldDatum': '/Date(1262300400000+0100)/',
#  'AantalBadkamers': None,
#  'AantalBeschikbaar': None,
#  'AantalKamers': None,
#  'AantalKavels': None,
#  'AantalSlaapkamers': None,
#  'AantalWoonlagen': None,
#  'Aanvaarding': 'In overleg',
#  'Adres': 'Zwartebessenstraat',
#  'AfgekochtDatum': None,
#  'Afstand': 0,
#  'BalkonDakterras': '',
#  'BedrijfsruimteCombinatieObject': None,
#  'BezichtingDagdelen': [],
#  'BezichtingDagen': [],
#  'BijdrageVVE': None,
#  'Bijzonderheden': '',
#  'Bouwjaar': None,
#  'Bouwvorm': None,
#  'BronCode': 'NVM',
#  'ChildrenObjects': [],
#  'ContactpersoonEmail': '',
#  'ContactpersoonTelefoon': '',
#  'Cv': None,
#  'DatumAanvaarding': None,
#  'DatumOndertekeningAkte': None,
#  'Deeplink': None,
#  'DetailInfo': {'HasPromotionLabel': False,
#   'PromotionLabelType': 0,
#   'RibbonColor': 0,
#   'RibbonText': None,
#   'Tagline': None},
#  'EersteHuurPrijs': None,
#  'EersteHuurPrijsLang': None,
#  'EersteKoopPrijs': None,
#  'EersteKoopPrijsLang': None,
#  'EigendomsSituatie': None,
#  'Energielabel': {'Definitief': False,
#   'Index': None,
#   'Label': None,
#   'NietBeschikbaar': False,
#   'NietVerplicht': False},
#  'ErfpachtBedrag': 0,
#  'Foto': 'http://cloud.funda.nl/valentina_media/021/380/521_klein.jpg',
#  'FotoLarge': 'http://cloud.funda.nl/valentina_media/021/380/521_groot.jpg',
#  'FotoLargest': 'http://cloud.funda.nl/valentina_media/021/380/521_grotere.jpg',
#  'FotoMedium': 'http://cloud.funda.nl/valentina_media/021/380/521_middel.jpg',
#  'FotoSecure': 'http://cloud.funda.nl/valentina_media/021/380/521_klein.jpg',
#  'Garage': None,
#  'GarageIsolatie': None,
#  'GarageVoorzieningen': None,
#  'GelegenOp': None,
#  'GewijzigdDatum': '/Date(1304895958000+0200)/',
#  'GlobalId': 1678142,
#  'GroupByObjectType': 'fa0638a9-2594-48bd-82ed-b88274bc1de7',
#  'Heeft360GradenFoto': False,
#  'HeeftBrochure': False,
#  'HeeftOpenhuizenTopper': False,
#  'HeeftOverbruggingsgrarantie': False,
#  'HeeftPlattegrond': False,
#  'HeeftTophuis': False,
#  'HeeftVeiling': False,
#  'HeeftVideo': False,
#  'HoofdFoto': 'http://cloud.funda.nl/valentina_media/021/380/521_groot.jpg',
#  'HoofdFotoSecure': 'http://cloud.funda.nl/valentina_media/021/380/521_groot.jpg',
#  'HoofdTuinType': None,
#  'HuurPrijs': None,
#  'HuurPrijsLang': None,
#  'HuurPrijsTot': None,
#  'Huurprijs': None,
#  'HuurprijsFormaat': None,
#  'Id': 1678142,
#  'InUnitsVanaf': None,
#  'IndBasisPlaatsing': True,
#  'IndFotos': True,
#  'IndIpix': False,
#  'IndOpenhuizenTopper': False,
#  'IndPDF': False,
#  'IndPlattegrond': False,
#  'IndProjectObjectType': False,
#  'IndTop': False,
#  'IndTransactieMakelaarTonen': None,
#  'IndVeilingProduct': False,
#  'IndVideo': False,
#  'Inhoud': None,
#  'InternalId': 'fa0638a9-2594-48bd-82ed-b88274bc1de7',
#  'IsIngetrokken': False,
#  'IsSearchable': True,
#  'IsVerhuurd': False,
#  'IsVerkocht': False,
#  'IsVerkochtOfVerhuurd': False,
#  'Isolatie': None,
#  'Kenmerken': [{'Ad': None,
#    'Kenmerken': [{'Naam': 'Vraagprijs',
#      'NaamCss': None,
#      'Waarde': '<span class="price-wrapper">€\xa0185.000 v.o.n.</span>',
#      'WaardeCss': None},
#     {'Naam': 'Aangeboden sinds',
#      'NaamCss': None,
#      'Waarde': '<span title="langer dan 6 maanden">6+ maanden</span>',
#      'WaardeCss': None},
#     {'Naam': 'Status',
#      'NaamCss': None,
#      'Waarde': 'Beschikbaar',
#      'WaardeCss': None},
#     {'Naam': 'Aanvaarding',
#      'NaamCss': None,
#      'Waarde': 'In overleg',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Overdracht'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Soort object',
#      'NaamCss': None,
#      'Waarde': 'Bouwgrond',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Bouw'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Perceeloppervlakte',
#      'NaamCss': None,
#      'Waarde': '1.510&nbsp;m&sup2;',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Indeling'},
#   {'Ad': None,
#    'Kenmerken': [{'Naam': 'Ligging',
#      'NaamCss': None,
#      'Waarde': 'Aan rustige weg, in woonwijk en beschutte ligging',
#      'WaardeCss': None}],
#    'SubKenmerk': None,
#    'Titel': 'Buitenruimte'}],
#  'KenmerkenKort': {'Ad': None,
#   'Kenmerken': [{'Naam': 'Soort object',
#     'NaamCss': None,
#     'Waarde': 'Bouwgrond',
#     'WaardeCss': None},
#    {'Naam': 'Perceeloppervlakte',
#     'NaamCss': None,
#     'Waarde': '1.510&nbsp;m&sup2;',
#     'WaardeCss': None},
#    {'Naam': 'Status',
#     'NaamCss': None,
#     'Waarde': 'Beschikbaar',
#     'WaardeCss': None},
#    {'Naam': 'Aanvaarding',
#     'NaamCss': None,
#     'Waarde': 'In overleg',
#     'WaardeCss': None}],
#   'SubKenmerk': None,
#   'Titel': None},
#  'KenmerkenTitel': None,
#  'KoopPrijs': 185000,
#  'KoopPrijsLang': '<[KoopPrijs]> <{vrij op naam|kort}>',
#  'Koopprijs': 185000,
#  'KoopprijsFormaat': '<[KoopPrijs]> <{vrij op naam|kort}>',
#  'KoopprijsTot': None,
#  'Ligging': 'aan rustige weg, in woonwijk en beschutte ligging',
#  'Makelaar': 'Steendijk Makelaar Taxateur o.g.',
#  'MakelaarId': 20101,
#  'MakelaarNaam': 'Steendijk Makelaar Taxateur o.g.',
#  'MakelaarTelefoon': '0113-219445',
#  'MedeAanbieders': [],
#  'Media': [{'Categorie': 1,
#    'ContentType': 1,
#    'Id': '3b0ce1e8-dbf3-43ee-97e2-1161ae68a2ac',
#    'IndexNumber': 1,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/021/380/521_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/021/380/521_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/021/380/521_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/021/380/521_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/021/380/521_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/021/380/521_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/021/380/521_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/021/380/521_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'geen',
#    'RegistratieVerplicht': False,
#    'Soort': 3},
#   {'Categorie': 1,
#    'ContentType': 1,
#    'Id': 'a4d977f7-03a2-459d-ba48-2bf8a17f82d7',
#    'IndexNumber': 2,
#    'MediaItems': [{'Category': 1,
#      'Height': 80,
#      'Url': 'http://cloud.funda.nl/valentina_media/021/380/522_klein.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/021/380/522_klein.jpg',
#      'Width': 121},
#     {'Category': 4,
#      'Height': 161,
#      'Url': 'http://cloud.funda.nl/valentina_media/021/380/522_middel.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/021/380/522_middel.jpg',
#      'Width': 242},
#     {'Category': 6,
#      'Height': 386,
#      'Url': 'http://cloud.funda.nl/valentina_media/021/380/522_groot.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/021/380/522_groot.jpg',
#      'Width': 580},
#     {'Category': 7,
#      'Height': 615,
#      'Url': 'http://cloud.funda.nl/valentina_media/021/380/522_grotere.jpg',
#      'UrlSecure': 'http://cloud.funda.nl/valentina_media/021/380/522_grotere.jpg',
#      'Width': 922}],
#    'Metadata': None,
#    'Omschrijving': 'geen',
#    'RegistratieVerplicht': False,
#    'Soort': 3}],
#  'Media-Foto': ['http://cloud.funda.nl/valentina_media/021/380/521_klein.jpg',
#   'http://cloud.funda.nl/valentina_media/021/380/522_klein.jpg'],
#  'MobileURL': 'http://m.funda.nl/koop/lewedorp/bouwgrond-47023505-zwartebessenstraat/',
#  'Note': None,
#  'ObjectType': 'bouwgrond',
#  'ObjectTypeMetVoorvoegsel': 'deze bouwgrond',
#  'OpenHuis': [],
#  'OpenHuizen': [],
#  'Oppervlakte': 0,
#  'PerceelOppervlakte': 1510,
#  'Perceeloppervlakte': 1510,
#  'PermanenteBewoning': None,
#  'Plaats': 'Lewedorp',
#  'Postcode': '4456CD',
#  'Prijs': {'GeenExtraKosten': None,
#   'HuurAbbreviation': '',
#   'Huurprijs': None,
#   'HuurprijsOpAanvraag': '',
#   'HuurprijsTot': None,
#   'KoopAbbreviation': 'v.o.n.',
#   'Koopprijs': 185000,
#   'KoopprijsOpAanvraag': '',
#   'KoopprijsTot': None,
#   'OriginelePrijs': None,
#   'VeilingText': ''},
#  'PrijsGeformatteerd': '<span class="price-wrapper"><span class="price">&euro;&nbsp;185.000</span> <abbr class="price-ext">v.o.n.</abbr></span>',
#  'PrijsGeformatteerdHtml': '<span class="price-wrapper"><span class="price">&euro;&nbsp;185.000</span> <abbr class="price-ext">v.o.n.</abbr></span>',
#  'PrijsGeformatteerdTextHuur': '<span class="price-wrapper"><span class="price">&euro;&nbsp;185.000</span> <abbr class="price-ext">v.o.n.</abbr></span>',
#  'PrijsGeformatteerdTextKoop': '<span class="price-wrapper"><span class="price">&euro;&nbsp;185.000</span> <abbr class="price-ext">v.o.n.</abbr></span>',
#  'Producten': [],
#  'Project': None,
#  'ProjectNaam': None,
#  'PromoLabel': {'HasPromotionLabel': False,
#   'PromotionPhotos': [],
#   'PromotionPhotosSecure': None,
#   'PromotionType': 0,
#   'RibbonColor': 0,
#   'RibbonText': None,
#   'Tagline': None},
#  'PublicatieDatum': '/Date(1304895958000+0200)/',
#  'PublicatieStatus': 0,
#  'SavedDate': None,
#  'SchuurBerging': None,
#  'SchuurBergingIsolatie': None,
#  'SchuurBergingVoorzieningen': None,
#  'ScrambledId': '47023505',
#  'ServiceKosten': None,
#  'ShortURL': 'http://funda.nl/47023505',
#  'Soort-aanbod': 'bouwgrond',
#  'SoortAanbod': 10,
#  'SoortDak': None,
#  'SoortGarage': 'bouwgrond',
#  'SoortParkeergelegenheid': 'bouwgrond',
#  'SoortPlaatsing': 0,
#  'SoortWoning': 'bouwgrond',
#  'StartOplevering': None,
#  'TimeAgoText': None,
#  'Titels': [{'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp',
#    'Pagina': 0},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Omschrijving',
#    'Pagina': 1},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Kenmerken',
#    'Pagina': 2},
#   {'Omschrijving': "Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Foto's",
#    'Pagina': 3},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Buurtinformatie',
#    'Pagina': 4},
#   {'Omschrijving': "Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Foto's",
#    'Pagina': 5},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Kaart',
#    'Pagina': 6},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Hypotheek',
#    'Pagina': 7},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Print',
#    'Pagina': 8},
#   {'Omschrijving': "Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - 360&deg; foto's",
#    'Pagina': 9},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Video',
#    'Pagina': 10},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Plattegrond',
#    'Pagina': 11},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Slideshow',
#    'Pagina': 12},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Reageer',
#    'Pagina': 13},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Bezichtiging',
#    'Pagina': 14},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Brochure',
#    'Pagina': 15},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Voorwaarden',
#    'Pagina': 16},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Openhuis',
#    'Pagina': 17},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Doorsturen',
#    'Pagina': 18},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Routeplanner',
#    'Pagina': 19},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Kadaster',
#    'Pagina': 20},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Overbruggingsgarantie',
#    'Pagina': 21},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - CarrouselBanner',
#    'Pagina': 22},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Carrousel',
#    'Pagina': 23},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - MeldEenFout',
#    'Pagina': 24},
#   {'Omschrijving': 'Bouwgrond te koop: Zwartebessenstraat 4456 CD Lewedorp - Woningtypen',
#    'Pagina': 25}],
#  'ToonBezichtigingMaken': False,
#  'ToonBrochureAanvraag': True,
#  'ToonMakelaarWoningaanbod': True,
#  'ToonReageren': True,
#  'TransactieAfmeldDatum': None,
#  'TransactieMakelaarId': None,
#  'TransactieMakelaarNaam': None,
#  'Tuin': '',
#  'TuinLigging': None,
#  'TypeProject': 0,
#  'URL': 'http://www.funda.nl/koop/lewedorp/bouwgrond-47023505-zwartebessenstraat/',
#  'Veiling': {'EindDatum': None,
#   'Link': None,
#   'StartDatum': None,
#   'VeilingPartij': None},
#  'VeilingGeformatteerd': None,
#  'VerkoopStatus': 'Beschikbaar',
#  'Verwarming': None,
#  'Video': None,
#  'VolledigeOmschrijving': "LEWEDORP: Vier prachtige landhuiskavels met zeer riante afmetingen!\n\nWest-Kraaijertpolder is een uitbreidingslokatie aan de zuidwestkant van Lewedorp. Het totale plan behelst de bouw van circa 70 woningen van zeer uiteenlopende types en waarin Bouwfonds Ontwikkeling uit Goes in totaal 38 'kant en klare' woningen heeft gerealiseerd. Voorts ontwikkelt Bouwfonds Ontwikkeling in deze fase een achttal zeer riante 'landhuiskavels', waarvan er nu vier te koop zijn.\nDe West-Kraaijertpolder is een ruim opgezette wijk, passend in de landelijke sfeer van de omgeving, met veel groen en rust, maar met een knipoog naar Goes en Middelburg welke op een steenworp afstand liggen.\n\nLewedorp maakt wonen heel compleet. \nLekker rustig gelegen in de landelijke dreven van het weidse polderland, maar wel met alle winkel-, sport- en recreatiemogelijkheden van de stad binnen handbereik met Heinkenszand, Middelburg en Goes op slechts enkele autominuten. Daar treft u alle winkels, uitgaan, veel beleving, recreatie en ontspanning. Terwijl u zich vervolgens weer terugtrekt in het landelijke groen van Lewedorp en de West-Kraaiertpolder. \nLewedorp behoort met haar circa 1700 inwoners tot één van de grotere kernen in de gemeente Borsele. Lewedorp heeft naast een eigen industrieterrein een goed ontwikkeld recreatiegebied, zoals 'De Piet' aan het Veerse Meer en het vliegveld 'Midden Zeeland'. Verder heeft Lewedorp voldoende eigen winkels om in de dagelijkse levensbehoeften te voorzien. \n\nDe West-Kraaijertpolder voldoet aan alle wensen van duurzaam wooncomfort. \nRust, landelijk, maar knus en sfeervol. Een relatief kleine sfeervollewijk, ruim opgezet. Zo is het groen van de natuur, waaraan de omgeving zo rijk is, doorgetrokken in de wijk. Eigenlijk is de West Kraaijertpolder puur genieten. Men kan er alle kanten op wat betreft bereikbaarheid. Maar het is ook een wijk waar de kinderen nog veilig op straat kunnen spelen.\nDe vier landhuiskavels liggen aan de rand van het uitbreidingsplan, tegen aan de Lewedijk. Alle percelen zijn individueel bereikbaar via een dam, welke over de aan de voorzijde van de percelen aangelegde watergang werd aangebracht. Deze dam, alsmede de in de watergang aangebrachte beschoeiing, blijft eigendom van de gemeente Borsele, wat vervolgens weer inhoudt dat ook het onderhoud hiervan voor haar rekening komt. \n\nDe riant en landelijk gelegen percelen worden inclusief beplanting geleverd. \nIn opdracht van Bouwfonds Ontwikkeling heeft Bosch Slabbers, tuin- en landschaparchitecten uit Middelburg, een groenplan ontwikkeld. \n\nPrijzen landhuiskavels: \nKavel 28  : circa 2.145 m²: verkoopsom € 185.000,-- v.o.n.\nKavel 28a: circa 3.710 m²: verkoopsom € 240.000,-- v.o.n.\nKavel 29  : circa 1.515 m²: verkoopsom € 175.000,-- v.o.n.\nKavel 29a: circa 2.662 m²: verkoopsom € 210.000,-- v.o.n.",
#  'Voorzieningen': None,
#  'WGS84_X': 3.746481,
#  'WGS84_Y': 51.4922867,
#  'WarmWater': None,
#  'WoonOppervlakte': None,
#  'WoonOppervlakteTot': None,
#  'Woonoppervlakte': None,
#  'Woonplaats': 'Lewedorp',
#  'ZoekType': [10]}

# %%
extraction_specs = [{'key': key} for key in KEY_NAMES]
extractor = DictMultiExtractor(extraction_specs, sep='.')
extractor(rawdicts[0])
# Out:
# {'AantalBadkamers': None,
#  'AantalKamers': 6,
#  'AantalWoonlagen': '1 woonlaag',
#  'Aanvaarding': 'In overleg',
#  'Adres': 'Sloestraat 19',
#  'AfgekochtDatum': None,
#  'BalkonDakterras': None,
#  'BijdrageVVE': None,
#  'Bijzonderheden': '',
#  'Bouwjaar': '2002',
#  'Bouwvorm': 'bestaande bouw',
#  'BronCode': 'VBO',
#  'EigendomsSituatie': 'volle eigendom',
#  'Energielabel.Definitief': False,
#  'Energielabel.Index': None,
#  'Energielabel.Label': 'B',
#  'Energielabel.NietBeschikbaar': False,
#  'Energielabel.NietVerplicht': False,
#  'ErfpachtBedrag': 0,
#  'Garage': 'aangebouwde stenen',
#  'GarageIsolatie': 'geen spouw',
#  'GarageVoorzieningen': None,
#  'GelegenOp': None,
#  'GlobalId': 3022972,
#  'Inhoud': 359,
#  'Isolatie': 'vloerisolatie, volledig geïsoleerd en dubbel glas',
#  'Koopprijs': 215000,
#  'Ligging': 'aan rustige weg',
#  'PerceelOppervlakte': 230,
#  'Perceeloppervlakte': 230,
#  'PermanenteBewoning': 'permanente bewoning is toegestaan',
#  'Postcode': '4456AN',
#  'PublicatieDatum': '/Date(1431387323000+0200)/',
#  'SchuurBerging': None,
#  'SchuurBergingIsolatie': None,
#  'SchuurBergingVoorzieningen': None,
#  'ServiceKosten': None,
#  'ShortURL': 'http://funda.nl/85831971',
#  'Soort-aanbod': 'woonhuis',
#  'SoortDak': 'zadeldak',
#  'SoortParkeergelegenheid': 'eengezinswoning, 2-onder-1-kapwoning',
#  'SoortPlaatsing': 1,
#  'SoortWoning': 'eengezinswoning, 2-onder-1-kapwoning',
#  'TuinLigging': None,
#  'Verwarming': 'C.V.-ketel',
#  'VolledigeOmschrijving': "Ruime 2 onder 1 kap woning met garage en zonnige achtertuin op het zuiden.\n \nObjectomschrijving\nGelegen in de kern van het vriendelijke Lewedorp.\nCentraal gelegen tussen de steden Goes, Middelburg en Vlissingen (allen bereikbaar in 15 auto minuten) staat deze goed onderhouden ruime 2-onder-1 kap woning (2002). De buurt / straat is rustig en kindvriendelijk. \nDeze woning heeft maar liefst 5 slaapkamers, een ruime garage met oprit, een groot dakterras en een gezellige, rustig gelegen en verzorgde tuin.\n \nMeer foto's kunt u vinden op de facebookpagina: Dit huis is te koop, Lewedorp\n\nBegane grond\nVia de entree kom je binnen in een hal waar zich het zwevend toilet met wastafeltje, de meterkast en de trap naar de eerste verdieping bevinden. \nVan daaruit kom je in een ruime en lichte L-vormige woonkamer met een gezellige gashaard. \nDe woonkamer heeft 3 ramen aan de voorzijde van het huis en openslaande tuindeuren naar het terras en tuin. \nDe wanden en het plafond van de woonkamer zijn gespoten stucwerk. Op de vloer ligt een antraciet flexxfloor. \nDe keuken is een moderne en lichte inbouwkeuken (Bruynzeel) v.v. alle benodigde apparatuur (grote koelkast, 90 cm brede Boretti heteluchtoven, een vijf-pits gasfornuis met wokbrander, afzuigkap, combi-magnetron en natuurlijk een vaatwasser). \nAansluitend vindt je de bijkeuken met daarin, over de hele breedte, een grote en diepe vaste voorraadkast met 3 schuifdeuren. \nAchter deze schuifdeuren is ook de wasmachineaansluiting. Via de bijkeuken kun je de ruime, inpandige, garage bereiken.\n \nTuin\nEr is een goed onderhouden tuin aan zowel de achterzijde als de voorzijde van het huis.\nAan de zijkant van het huis is een afdak gemaakt waar alle ruimte is voor de verschillende afvalcontainers en nog veel meer. \nDe rustig gelegen en gezellige achtertuin is aangelegd met veel vaste planten en groen en heeft twee terrassen en een grote vijver. \nDe achtertuin is bereikbaar via de garage, bijkeuken en woonkamer en heeft ook een poort aan de zijkant van het huis. \nDe tuin ligt op het zuiden.\n \nEerste verdieping\nOp de eerste verdieping vind je 3 slaapkamers waarvan er 1 momenteel in gebruik is als werk-/hobbykamer. \nDeze werk-/hobbykamer bevindt zich samen met de ouderslaapkamer aan de voorzijde van het huis. \nAlle slaapkamers, ook de twee op de zolderverdieping, zijn voorzien van een laminaatvloer. \nAan de achterzijde bevindt zich nog een slaapkamer en een moderne en lichte badkamer. \nDe badkamer is v.v. een ligbad en een aparte douchecabine, een zwevend toilet en een wastafelmeubel met spiegel en verlichting. \nDe badkamer is betegeld met een lichte en neutrale tegel met bijpassende vloertegels en beschikt over mechanische afzuiging en een designradiator.\n \nZolderverdieping\nVia een vaste trap kom je bij een grote zolderverdieping. Hier vind je naast twee slaapkamers, veel extra bergruimte, de CV-combiketel en een wastafelmeubel met spiegel en verlichting. \nDe zolderverdieping is aan de achterzijde voorzien van een grote dakkapel van kunststof, met draai- kiepramen en rolluiken. \nAan de voorzijde zijn twee grote Velux dakramen geplaatst.\n \nOverig\nDeze woning biedt als extra nog een ruim dakterras met windscherm en welke is betegeld met rubber terrastegels. \nDit dakterras bevindt zich boven de bijkeuken en een groot deel van de garage en is via de tuin bereikbaar met een vaste, RVS buitentrap. \nHet dakterras is gelegen op het zuidoosten en heeft de gehele dag zon.\n \nBijzonderheden\nCV-combiketel (Nefit) 2002 \ngrote kunststof dakkapel met rolluiken 2010 \ngroot dakterras 2013\ndubbel glas \ngladde vloeren in het hele huis (flexxfloor, laminaat, tegels) \nafzuigkap 2014 \nkoelkast 2012\ncombi magnetron 2013\nbuitenschilderwerk 2015\nindien gewenst ook gemeubileerd te koop\n \nAanvaarding\nin overleg\n\n**Voor meer info en alle foto's, Google op AANTREKKELIJKHUIS**",
#  'Voorzieningen': 'mechanische ventilatie, rolluiken en buitenzonwering',
#  'WGS84_X': 3.750296,
#  'WGS84_Y': 51.4944725,
#  'WarmWater': 'C.V.-ketel',
#  'WoonOppervlakte': 116,
#  'Woonplaats': 'Lewedorp'}

# %%
df =  extract_preliminary(pd.Series(rawdicts), KEY_NAMES)
san_df = sanitize_data(df)

# %%
san_df['Koopprijs']
# Out:
# 0     215000.0
# 1     137500.0
# 2     389000.0
# 3     363000.0
# 4     490000.0
# 5     529000.0
# 6     499999.0
# 7     359000.0
# 8     149000.0
# 9     250000.0
# 10    185000.0
# 11    315000.0
# 12    179500.0
# 13    189000.0
# 14    159000.0
# 15    225000.0
# 16    185000.0
# 17    239000.0
# Name: Koopprijs, dtype: float64

# %%
san_df.drop('VolledigeOmschrijving', axis='columns').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 0 to 17
# Data columns (total 46 columns):
# AantalBadkamers                 9 non-null float64
# AantalKamers                    17 non-null float64
# BijdrageVVE                     0 non-null float64
# Energielabel.Definitief         18 non-null float64
# Energielabel.Index              0 non-null float64
# Energielabel.NietBeschikbaar    18 non-null float64
# Energielabel.NietVerplicht      18 non-null float64
# ErfpachtBedrag                  16 non-null float64
# Inhoud                          15 non-null float64
# PerceelOppervlakte              16 non-null float64
# ServiceKosten                   6 non-null float64
# SoortPlaatsing                  18 non-null float64
# WoonOppervlakte                 15 non-null float64
# WGS84_X                         18 non-null float64
# WGS84_Y                         18 non-null float64
# Koopprijs                       18 non-null float64
# PublicatieDatum                 18 non-null datetime64[ns]
# Bouwjaar                        17 non-null float64
# AantalWoonlagen                 15 non-null float64
# Aanvaarding                     16 non-null object
# Bouwvorm                        17 non-null object
# BronCode                        18 non-null object
# Energielabel.Label              17 non-null object
# PermanenteBewoning              15 non-null object
# SchuurBerging                   9 non-null object
# Soort-aanbod                    18 non-null object
# TuinLigging                     8 non-null object
# Woonplaats                      18 non-null object
# Voorzieningen                   8 non-null object
# GarageVoorzieningen             6 non-null object
# SoortDak                        15 non-null object
# GarageIsolatie                  6 non-null object
# Ligging                         16 non-null object
# EigendomsSituatie               11 non-null object
# SchuurBergingIsolatie           3 non-null object
# Bijzonderheden                  16 non-null object
# BalkonDakterras                 1 non-null object
# WarmWater                       15 non-null object
# SoortWoning                     17 non-null object
# Verwarming                      15 non-null object
# SoortParkeergelegenheid         16 non-null object
# Garage                          9 non-null object
# Isolatie                        15 non-null object
# SchuurBergingVoorzieningen      6 non-null object
# GlobalId                        18 non-null int64
# ShortURL                        18 non-null object
# dtypes: datetime64[ns](1), float64(18), int64(1), object(26)
# memory usage: 7.2+ KB

# %%
sanitize_record(rawdicts[0])
# Out:
# {'AantalBadkamers': nan,
#  'AantalKamers': 6.0,
#  'AantalWoonlagen': 1,
#  'Aanvaarding': 'In overleg',
#  'BalkonDakterras': None,
#  'BijdrageVVE': nan,
#  'Bijzonderheden': '',
#  'Bouwjaar': 2002.0,
#  'Bouwvorm': 'bestaande bouw',
#  'BronCode': 'VBO',
#  'EigendomsSituatie': 'volle eigendom',
#  'Energielabel.Definitief': 0.0,
#  'Energielabel.Index': nan,
#  'Energielabel.Label': 'B',
#  'Energielabel.NietBeschikbaar': 0.0,
#  'Energielabel.NietVerplicht': 0.0,
#  'ErfpachtBedrag': 0.0,
#  'Garage': 'aangebouwde stenen',
#  'GarageIsolatie': 'geen spouw',
#  'GarageVoorzieningen': None,
#  'GlobalId': 3022972,
#  'Inhoud': 359.0,
#  'Isolatie': 'vloerisolatie, volledig geïsoleerd en dubbel glas',
#  'Koopprijs': 215000.0,
#  'Ligging': 'aan rustige weg',
#  'PerceelOppervlakte': 230.0,
#  'PermanenteBewoning': 'permanente bewoning is toegestaan',
#  'PublicatieDatum': Timestamp('2015-05-12 02:35:23'),
#  'SchuurBerging': None,
#  'SchuurBergingIsolatie': None,
#  'SchuurBergingVoorzieningen': None,
#  'ServiceKosten': nan,
#  'ShortURL': 'http://funda.nl/85831971',
#  'Soort-aanbod': 'woonhuis',
#  'SoortDak': 'zadeldak',
#  'SoortParkeergelegenheid': 'eengezinswoning, 2-onder-1-kapwoning',
#  'SoortPlaatsing': 1.0,
#  'SoortWoning': 'eengezinswoning, 2-onder-1-kapwoning',
#  'TuinLigging': None,
#  'Verwarming': 'C.V.-ketel',
#  'VolledigeOmschrijving': "Ruime 2 onder 1 kap woning met garage en zonnige achtertuin op het zuiden.\n \nObjectomschrijving\nGelegen in de kern van het vriendelijke Lewedorp.\nCentraal gelegen tussen de steden Goes, Middelburg en Vlissingen (allen bereikbaar in 15 auto minuten) staat deze goed onderhouden ruime 2-onder-1 kap woning (2002). De buurt / straat is rustig en kindvriendelijk. \nDeze woning heeft maar liefst 5 slaapkamers, een ruime garage met oprit, een groot dakterras en een gezellige, rustig gelegen en verzorgde tuin.\n \nMeer foto's kunt u vinden op de facebookpagina: Dit huis is te koop, Lewedorp\n\nBegane grond\nVia de entree kom je binnen in een hal waar zich het zwevend toilet met wastafeltje, de meterkast en de trap naar de eerste verdieping bevinden. \nVan daaruit kom je in een ruime en lichte L-vormige woonkamer met een gezellige gashaard. \nDe woonkamer heeft 3 ramen aan de voorzijde van het huis en openslaande tuindeuren naar het terras en tuin. \nDe wanden en het plafond van de woonkamer zijn gespoten stucwerk. Op de vloer ligt een antraciet flexxfloor. \nDe keuken is een moderne en lichte inbouwkeuken (Bruynzeel) v.v. alle benodigde apparatuur (grote koelkast, 90 cm brede Boretti heteluchtoven, een vijf-pits gasfornuis met wokbrander, afzuigkap, combi-magnetron en natuurlijk een vaatwasser). \nAansluitend vindt je de bijkeuken met daarin, over de hele breedte, een grote en diepe vaste voorraadkast met 3 schuifdeuren. \nAchter deze schuifdeuren is ook de wasmachineaansluiting. Via de bijkeuken kun je de ruime, inpandige, garage bereiken.\n \nTuin\nEr is een goed onderhouden tuin aan zowel de achterzijde als de voorzijde van het huis.\nAan de zijkant van het huis is een afdak gemaakt waar alle ruimte is voor de verschillende afvalcontainers en nog veel meer. \nDe rustig gelegen en gezellige achtertuin is aangelegd met veel vaste planten en groen en heeft twee terrassen en een grote vijver. \nDe achtertuin is bereikbaar via de garage, bijkeuken en woonkamer en heeft ook een poort aan de zijkant van het huis. \nDe tuin ligt op het zuiden.\n \nEerste verdieping\nOp de eerste verdieping vind je 3 slaapkamers waarvan er 1 momenteel in gebruik is als werk-/hobbykamer. \nDeze werk-/hobbykamer bevindt zich samen met de ouderslaapkamer aan de voorzijde van het huis. \nAlle slaapkamers, ook de twee op de zolderverdieping, zijn voorzien van een laminaatvloer. \nAan de achterzijde bevindt zich nog een slaapkamer en een moderne en lichte badkamer. \nDe badkamer is v.v. een ligbad en een aparte douchecabine, een zwevend toilet en een wastafelmeubel met spiegel en verlichting. \nDe badkamer is betegeld met een lichte en neutrale tegel met bijpassende vloertegels en beschikt over mechanische afzuiging en een designradiator.\n \nZolderverdieping\nVia een vaste trap kom je bij een grote zolderverdieping. Hier vind je naast twee slaapkamers, veel extra bergruimte, de CV-combiketel en een wastafelmeubel met spiegel en verlichting. \nDe zolderverdieping is aan de achterzijde voorzien van een grote dakkapel van kunststof, met draai- kiepramen en rolluiken. \nAan de voorzijde zijn twee grote Velux dakramen geplaatst.\n \nOverig\nDeze woning biedt als extra nog een ruim dakterras met windscherm en welke is betegeld met rubber terrastegels. \nDit dakterras bevindt zich boven de bijkeuken en een groot deel van de garage en is via de tuin bereikbaar met een vaste, RVS buitentrap. \nHet dakterras is gelegen op het zuidoosten en heeft de gehele dag zon.\n \nBijzonderheden\nCV-combiketel (Nefit) 2002 \ngrote kunststof dakkapel met rolluiken 2010 \ngroot dakterras 2013\ndubbel glas \ngladde vloeren in het hele huis (flexxfloor, laminaat, tegels) \nafzuigkap 2014 \nkoelkast 2012\ncombi magnetron 2013\nbuitenschilderwerk 2015\nindien gewenst ook gemeubileerd te koop\n \nAanvaarding\nin overleg\n\n**Voor meer info en alle foto's, Google op AANTREKKELIJKHUIS**",
#  'Voorzieningen': 'mechanische ventilatie, rolluiken en buitenzonwering',
#  'WGS84_X': 3.750296,
#  'WGS84_Y': 51.4944725,
#  'WarmWater': 'C.V.-ketel',
#  'WoonOppervlakte': 116.0,
#  'Woonplaats': 'Lewedorp'}
